# %%
import matplotlib.pyplot as plt
import pickle
with open ('../statistics.pkl', 'rb') as fo:
    data = pickle.load(fo)

# %%
plt.plot(data['best_mean_episode_rewards'])

# %%
plt.plot(data['mean_episode_rewards'])
